# %%
# !pip install easyocr pdf2image presidio-analyzer spacy Pillow certifi
# Out:
# ...
#   Using cached easyocr-1.7.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached presidio_analyzer-2.2.354-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached spacy-3.7.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (27 kB)
# ...
#   Using cached torch-2.3.0-cp311-none-macosx_11_0_arm64.whl.metadata (26 kB)
# ...
#   Using cached torchvision-0.18.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# ...
#   Using cached opencv_python_headless-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# ...
#   Using cached python_bidi-0.4.2-py2.py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached shapely-2.0.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.0 kB)
# ...
#   Using cached pyclipper-1.3.0.post5-cp311-cp311-macosx_10_9_universal2.whl.metadata (9.0 kB)
# ...
#   Using cached ninja-1.11.1.1-py2.py3-none-macosx_10_9_universal2.macosx_10_9_x86_64.macosx_11_0_arm64.macosx_11_0_universal2.whl.metadata (5.3 kB)
# ...

# %%
import ssl
import certifi
import easyocr
import spacy
from pdf2image import convert_from_path
from presidio_analyzer import AnalyzerEngine, PatternRecognizer
from presidio_analyzer.nlp_engine import SpacyNlpEngine, NlpEngine
from PIL import Image, ImageDraw

image_path = "/Users/ambarishdeshpande/LTIMindtree/PIIMaskingProject/receipt.png"

images = convert_from_path(image_path)
reader = easyocr.Reader(['en'])
results = reader.readtext(image_path, detail=1)
print(results)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pdf2image/pdf2image.py:581, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout, first_page, last_page)
#     580     env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 581 proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     583 try:
#
# File /opt/anaconda3/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# ...
